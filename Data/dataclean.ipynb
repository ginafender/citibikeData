# %%
import pandas as pd

# %%
old = pd.read_csv("C:/Users/ginav/Desktop/Analysis Projects/Class Activity Files/Module 18/Data/202205-citibike-tripdata.csv", low_memory=False)
old_df = pd.DataFrame(old)
old_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  F49280E52B6491D8  electric_bike  2022-05-16 16:58:35  2022-05-16 17:08:56
# 1  B587F12BCC6778B0  electric_bike  2022-05-19 17:41:41  2022-05-19 17:53:35
# 2  D89D4D15B4E42A23   classic_bike  2022-05-27 08:34:05  2022-05-27 08:37:38
# 3  94B921DF9913EB66  electric_bike  2022-05-13 22:25:06  2022-05-13 22:51:29
# 4  B81A75AC39BA13E1   classic_bike  2022-05-13 09:16:56  2022-05-13 09:24:25
#
#                               start_station_name start_station_id  \
# 0  Central Park North & Adam Clayton Powell Blvd          7617.07
# 1                             Broadway & E 19 St          6098.12
# 2                   Rockaway Ave & Bainbridge St          4285.09
# 3                        Lexington Ave & E 36 St          6313.10
# 4                       Willoughby Ave & Hall St          4611.03
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# ...

# %%
old_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2940600 entries, 0 to 2940599
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 291.7+ MB

# %%
old_df['started_at'] = pd.to_datetime(old_df['started_at'])

old_df['ended_at'] = pd.to_datetime(old_df['ended_at'])

old_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2940600 entries, 0 to 2940599
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: datetime64[ns](2), float64(4), object(7)
# memory usage: 291.7+ MB

# %%
new = pd.read_csv("C:/Users/ginav/Desktop/Analysis Projects/Class Activity Files/Module 18/Data/202305-citibike-tripdata.csv", low_memory=False)
new_df = pd.DataFrame(new)
new_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  176B188F3289F37B   classic_bike  2023-05-23 19:22:53  2023-05-23 19:35:23
# 1  BB6957A02501C686   classic_bike  2023-05-27 08:49:55  2023-05-27 08:57:42
# 2  C67567E1DAFB9F2C   classic_bike  2023-05-12 20:19:58  2023-05-12 20:36:07
# 3  89DDFCEAE05D043A  electric_bike  2023-05-03 07:59:13  2023-05-03 08:07:04
# 4  63B1D5A7A2316252   classic_bike  2023-05-13 10:23:52  2023-05-13 10:47:17
#
#          start_station_name start_station_id  \
# 0        E 50 St & Park Ave          6659.10
# 1  Flatbush Ave & Ocean Ave          3704.04
# 2  Flatbush Ave & Ocean Ave          3704.04
# 3  Flatbush Ave & Ocean Ave          3704.04
# 4  Flatbush Ave & Ocean Ave          3704.04
#
#                    end_station_name end_station_id  start_lat  start_lng  \
# 0                   E 74 St & 1 Ave        6953.08  40.757306 -73.974518
# 1  Grand Army Plaza & Plaza St West        4010.15  40.663657 -73.963014
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3580766 entries, 0 to 3580765
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 355.1+ MB

# %%
new_df['started_at'] = pd.to_datetime(new_df['started_at'])

new_df['ended_at'] = pd.to_datetime(new_df['ended_at'])

new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3580766 entries, 0 to 3580765
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: datetime64[ns](2), float64(4), object(7)
# memory usage: 355.1+ MB

# %%
combined_df = old_df.merge(new_df, how='outer')
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6521366 entries, 0 to 6521365
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: datetime64[ns](2), float64(4), object(7)
# memory usage: 646.8+ MB

# %%
combined_df.to_csv("C:/Users/ginav/Desktop/Analysis Projects/Class Activity Files/Module 18/citibikeData/Data/fulldata.csv")
